# %%
import main
import pandas as pd

url = "https://ai-process-sandy.s3.eu-west-1.amazonaws.com/purge/deviation.json"

# параметры - draw_plots([url адрес], [показать конкретный id], [количество итераций=int], [тип графика='line'/'colum'])
data = main.draw_plots(url, False, max_iteration=5)

data_frame = pd.DataFrame(data)
data_frame
# Out:
#   id_number          name  gt_corners  rb_corners       mean        max  \
# 0         0  Schlafzimmer         4.0         4.0   3.956313   8.562939
# 1         1         Küche         4.0         4.0  23.019122  52.605437
# 2         2      Bathroom         4.0         4.0   1.013833   1.950322
# 3         3  Lounge/Diner         8.0         8.0   3.832620  18.236935
# 4         4    Essbereich         4.0         4.0   8.017758  15.642853
#
#         min  floor_mean  floor_max  floor_min  ceiling_mean  ceiling_max  \
# 0  0.274574    3.987864   8.562939   0.274574      3.924762     8.501885
# 1  0.724299    1.253103   1.897612   0.724299     44.785141    52.605437
# 2  0.301673    0.659138   1.318714   0.301673      1.368528     1.950322
# 3  0.173307    3.600083  15.041431   0.173307      4.065157    18.236935
# 4  0.762948    7.819446  15.399635   0.762948      8.216069    15.642853
#
#    ceiling_min
# 0     0.331494
# 1    36.880814
# 2     0.878106
# 3     0.253457
# ...
